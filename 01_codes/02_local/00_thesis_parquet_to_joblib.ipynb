# %%
import pandas as pd
import joblib

# %%
tweet_0_pt_1 = pd.read_parquet("../../02_data/raw/tweet_0_pt_1.parquet")
tweet_0_pt_2 = pd.read_parquet("../../02_data/raw/tweet_0_pt_2.parquet")

tweet_df = pd.concat([tweet_0_pt_1, tweet_0_pt_2])
tweet_df.head(1)

# %%
tweet_0_pt_1 = pd.read_parquet("../../02_data/raw/tweet_0_pt_1.parquet")
tweet_0_pt_1.head()

# %%
joblib.dump(tweet_df, f"../../02_data/raw/tweet_0.joblib")
