# %%
import pandas as pd
import joblib

# %%
tweet_0_pt_1 = pd.read_parquet("../../02_data/raw/tweet_0_pt_1.parquet", engine="fastparquet")
tweet_0_pt_2 = pd.read_parquet("../../02_data/raw/tweet_0_pt_2.parquet", engine="fastparquet")

tweet_df = pd.concat([tweet_0_pt_1, tweet_0_pt_2])
tweet_df.head(1)
# Out:
#      author_id context_annotations      conversation_id  \
# 0  391092102.0                None  1502784561763295233
#
#                   created_at                    id  in_reply_to_user_id lang  \
# 0  2022-03-12 23:12:14+00:00  t1502784561763295233                  NaN   en
#
#    possibly_sensitive referenced_tweets reply_settings  ... geo.coordinates  \
# 0                 0.0              None       everyone  ...            None
#
#   geo.place_id geo.type public_metrics.like_count public_metrics.quote_count  \
# 0         None     None                       0.0                        0.0
#
#   public_metrics.reply_count public_metrics.retweet_count withheld.copyright  \
# 0                        0.0                         42.0                NaN
#
#   withheld.country_codes withheld.scope
# 0                   None           None
#
# [1 rows x 32 columns]

# %%
tweet_df["author_id"] = "u" + tweet_df["author_id"].astype("Int64").astype(str)
tweet_df["created_at"] = pd.to_datetime(tweet_df["created_at"], utc=True)

# %%
if tweet_df.isnull().any().any():
    print("Missing values found in the dataset.")
    na_summary = tweet_df.isnull().sum().loc[lambda x: x > 0].to_frame(name='Missing Count')
    na_summary['Missing Percentage'] = (na_summary['Missing Count'] / tweet_df.shape[0]) * 100
    print("\nSummary of missing values:")
    print(na_summary)
else:
    print("No missing values found in the dataset.")
# Out:
# Missing values found in the dataset.
#
# Summary of missing values:
#                             Missing Count  Missing Percentage
# context_annotations              10000000           100.00000
# in_reply_to_user_id               7360171            73.60171
# referenced_tweets                10000000           100.00000
# reply_settings                    9175227            91.75227
# attachments.media_keys            9785046            97.85046
# attachments.poll_ids              9785046            97.85046
# entities.annotations             10000000           100.00000
# entities.cashtags                10000000           100.00000
# entities.hashtags                10000000           100.00000
# entities.media                   10000000           100.00000
# entities.mentions                10000000           100.00000
# entities.symbols                 10000000           100.00000
# entities.urls                    10000000           100.00000
# entities.user_mentions           10000000           100.00000
# geo.coordinates                   9983298            99.83298
# geo.place_id                      9988466            99.88466
# geo.type                          9984648            99.84648
# public_metrics.quote_count        9175227            91.75227
# public_metrics.reply_count        9175227            91.75227
# withheld.copyright                9999709            99.99709
# withheld.country_codes            9999709            99.99709
# withheld.scope                    9999999            99.99999

# %%
tw_cols_to_drop = [
    "context_annotations",
    "referenced_tweets",
    "entities.annotations",
    "entities.cashtags",
    "entities.hashtags",
    "entities.media",
    "entities.mentions",
    "entities.symbols",
    "entities.urls",
    "entities.user_mentions"
]

tweet_df_1 = tweet_df.drop(columns=tw_cols_to_drop)
tweet_df_1.head(1)
# Out:
#     author_id      conversation_id                created_at  \
# 0  u391092102  1502784561763295233 2022-03-12 23:12:14+00:00
#
#                      id  in_reply_to_user_id lang  possibly_sensitive  \
# 0  t1502784561763295233                  NaN   en                 0.0
#
#   reply_settings           source  \
# 0       everyone  Twitter Web App
#
#                                                 text  ... geo.coordinates  \
# 0  RT @ChelseaSTrust: Join the CST now.\n\n#Toget...  ...            None
#
#   geo.place_id geo.type public_metrics.like_count public_metrics.quote_count  \
# 0         None     None                       0.0                        0.0
#
#    public_metrics.reply_count  public_metrics.retweet_count  \
# 0                         0.0                          42.0
#
#    withheld.copyright  withheld.country_codes  withheld.scope
# 0                 NaN                    None            None
#
# [1 rows x 22 columns]

# %%
user_df = pd.read_parquet("../../02_data/raw/user.parquet", engine="fastparquet")
user_df.head(1)
# Out:
#                   created_at  \
# 0  2020-01-16 02:02:55+00:00
#
#                                          description                    id  \
# 0  Theoretical Computer Scientist. See also https...  u1217628182611927040
#
#         location        name  pinned_tweet_id  \
# 0  Cambridge, MA  Boaz Barak              NaN
#
#                                    profile_image_url  protected  \
# 0  https://pbs.twimg.com/profile_images/125226236...        0.0
#
#                        url      username  ...  entities.description.cashtags  \
# 0  https://t.co/BoMip9FF17  boazbaraktcs  ...                           None
#
#   entities.description.hashtags entities.description.mentions  \
# 0                          None                          None
#
#   entities.description.urls entities.url.urls public_metrics.followers_count  \
# 0                      None              None                         7316.0
#
#    public_metrics.following_count  public_metrics.listed_count  \
# 0                           215.0                         69.0
#
#    public_metrics.tweet_count  withheld.country_codes
# 0                      3098.0                    None
#
# [1 rows x 21 columns]

# %%
label_df = pd.read_csv(f"../../02_data/raw/label.csv")
label_df.head()
# Out:
#                      id  label
# 0  u1217628182611927040  human
# 1           u2664730894  human
# 2  u1266703520205549568  human
# 3  u1089159225148882949  human
# 4             u36741729    bot

# %%
user_df_1 = user_df.merge(
    label_df,
    on="id",
    how="left"
    )
user_df_1.head(1)
# Out:
#                   created_at  \
# 0  2020-01-16 02:02:55+00:00
#
#                                          description                    id  \
# 0  Theoretical Computer Scientist. See also https...  u1217628182611927040
#
#         location        name  pinned_tweet_id  \
# 0  Cambridge, MA  Boaz Barak              NaN
#
#                                    profile_image_url  protected  \
# 0  https://pbs.twimg.com/profile_images/125226236...        0.0
#
#                        url      username  ...  entities.description.hashtags  \
# 0  https://t.co/BoMip9FF17  boazbaraktcs  ...                           None
#
#   entities.description.mentions entities.description.urls entities.url.urls  \
# 0                          None                      None              None
#
#   public_metrics.followers_count public_metrics.following_count  \
# 0                         7316.0                          215.0
#
#    public_metrics.listed_count  public_metrics.tweet_count  \
# 0                         69.0                      3098.0
#
#    withheld.country_codes  label
# 0                    None  human
#
# [1 rows x 22 columns]

# %%
user_df_subset = user_df_1[user_df_1["id"].isin(tweet_df_1["author_id"])].copy()
user_df_subset.shape
# Out:
# (268238, 22)

# %%
tweet_df_1["pct_pl"] = tweet_df_1["lang"].eq("pl").groupby(tweet_df_1["author_id"]).transform("mean")

user_df_subset_1 = user_df_subset.merge(
    tweet_df_1[["author_id", "pct_pl"]].drop_duplicates(),
    left_on="id",
    right_on="author_id",
    how="left"
    ).drop(columns="author_id")
user_df_subset_1.head()
# Out:
#                   created_at  \
# 0  2020-01-16 02:02:55+00:00
# 1  2008-06-23 20:59:59+00:00
# 2  2014-04-27 00:20:12+00:00
# 3  2011-04-20 03:30:01+00:00
# 4  2009-10-18 16:06:58+00:00
#
#                                          description                    id  \
# 0  Theoretical Computer Scientist. See also https...  u1217628182611927040
# 1  Director, Knowledge Ecology International, an ...             u15211869
# 2                         paper tweets, dms are open           u2465283662
# 3  Assistant prof @NottsPolitics | institutional ...            u284870222
# 4  Creative developer • Freelancer • Teacher • We...             u83389771
#
#                   location         name  pinned_tweet_id  \
# 0            Cambridge, MA   Boaz Barak              NaN
# 1  ÜT: 38.911326,-77.04508   James Love     1.335259e+18
# 2                     None           AK              NaN
# 3           Nottingham, UK   Anna Meier     1.303136e+18
# 4                    Paris  Bruno Simon     1.351508e+18
#
#                                    profile_image_url  protected  \
# 0  https://pbs.twimg.com/profile_images/125226236...        0.0
# 1  https://pbs.twimg.com/profile_images/126138453...        0.0
# 2  https://pbs.twimg.com/profile_images/145119163...        0.0
# 3  https://pbs.twimg.com/profile_images/145636471...        0.0
# 4  https://pbs.twimg.com/profile_images/123799977...        0.0
#
#                        url      username  ...  entities.description.mentions  \
# 0  https://t.co/BoMip9FF17  boazbaraktcs  ...                           None
# 1  https://t.co/mcNZxOR7gv    jamie_love  ...                           None
# 2                                ak92501  ...                           None
# 3  https://t.co/bnWgIr4Oyv   AnnaMeierPS  ...                           None
# 4  https://t.co/UEPMHqG4nV   bruno_simon  ...                           None
#
#   entities.description.urls entities.url.urls public_metrics.followers_count  \
# 0                      None              None                         7316.0
# 1                      None              None                        10299.0
# 2                      None              None                        45541.0
# 3                      None              None                         9490.0
# 4                      None              None                        33173.0
#
#   public_metrics.following_count public_metrics.listed_count  \
# 0                          215.0                        69.0
# 1                         2166.0                       383.0
# 2                         1206.0                       605.0
# 3                         2146.0                        93.0
# 4                          414.0                       417.0
#
#    public_metrics.tweet_count  withheld.country_codes  label  pct_pl
# 0                      3098.0                    None  human     0.0
# 1                     57397.0                    None  human     0.0
# 2                      9194.0                    None    bot     0.0
# 3                     19122.0                    None  human     0.0
# 4                      5132.0                    None  human     0.0
#
# [5 rows x 23 columns]

# %%
user_df_subset_pl = user_df_subset_1[user_df_subset_1["pct_pl"] >= 0.9].copy()
user_df_subset_pl.drop(columns="pct_pl", inplace=True)

user_df_subset_pl.head(1)
# Out:
#                      created_at  \
# 7685  2009-07-22 23:40:16+00:00
#
#                                             description         id  \
# 7685  👨‍💻 Software developer for 20+ years (full-sta...  u59291478
#
#             location                name  pinned_tweet_id  \
# 7685  Cardiff, Wales  Savvas Stephanides     1.480580e+18
#
#                                       profile_image_url  protected  \
# 7685  https://pbs.twimg.com/profile_images/147983948...        0.0
#
#                           url        username  ...  \
# 7685  https://t.co/LbRwXBRHbe  SavvasStephnds  ...
#
#       entities.description.hashtags entities.description.mentions  \
# 7685                           None                          None
#
#      entities.description.urls entities.url.urls  \
# 7685                      None              None
#
#      public_metrics.followers_count public_metrics.following_count  \
# 7685                         3521.0                          423.0
#
#       public_metrics.listed_count  public_metrics.tweet_count  \
# 7685                         83.0                     11818.0
#
#       withheld.country_codes  label
# 7685                    None  human
#
# [1 rows x 22 columns]

# %%
user_df_subset_non_pl = user_df_subset_1[user_df_subset_1["pct_pl"] < 0.9].copy()
user_df_subset_non_pl.drop(columns="pct_pl", inplace=True)

user_df_subset_non_pl.head(1)
# Out:
#                   created_at  \
# 0  2020-01-16 02:02:55+00:00
#
#                                          description                    id  \
# 0  Theoretical Computer Scientist. See also https...  u1217628182611927040
#
#         location        name  pinned_tweet_id  \
# 0  Cambridge, MA  Boaz Barak              NaN
#
#                                    profile_image_url  protected  \
# 0  https://pbs.twimg.com/profile_images/125226236...        0.0
#
#                        url      username  ...  entities.description.hashtags  \
# 0  https://t.co/BoMip9FF17  boazbaraktcs  ...                           None
#
#   entities.description.mentions entities.description.urls entities.url.urls  \
# 0                          None                      None              None
#
#   public_metrics.followers_count public_metrics.following_count  \
# 0                         7316.0                          215.0
#
#    public_metrics.listed_count  public_metrics.tweet_count  \
# 0                         69.0                      3098.0
#
#    withheld.country_codes  label
# 0                    None  human
#
# [1 rows x 22 columns]

# %%
user_df_subset_1["label"].value_counts(normalize=True)
# Out:
# label
# human    0.936959
# bot      0.063041
# Name: proportion, dtype: float64

# %%
user_df_subset_pl["label"].value_counts(normalize=True)
# Out:
# label
# human    0.952703
# bot      0.047297
# Name: proportion, dtype: float64

# %%
user_df_subset_non_pl["label"].value_counts(normalize=True)
# Out:
# label
# human    0.93695
# bot      0.06305
# Name: proportion, dtype: float64

# %%
tweet_df_pl = tweet_df_1[tweet_df_1["author_id"].isin(user_df_subset_pl["id"])].copy()
tweet_df_pl.shape
# Out:
# (2690, 23)

# %%
tweet_df_non_pl = tweet_df_1[~tweet_df_1["author_id"].isin(user_df_subset_pl["id"])].copy()
tweet_df_non_pl.shape
# Out:
# (9997310, 23)

# %%
user_df_subset_non_pl.head(1)
# Out:
#                   created_at  \
# 0  2020-01-16 02:02:55+00:00
#
#                                          description                    id  \
# 0  Theoretical Computer Scientist. See also https...  u1217628182611927040
#
#         location        name  pinned_tweet_id  \
# 0  Cambridge, MA  Boaz Barak              NaN
#
#                                    profile_image_url  protected  \
# 0  https://pbs.twimg.com/profile_images/125226236...        0.0
#
#                        url      username  ...  entities.description.hashtags  \
# 0  https://t.co/BoMip9FF17  boazbaraktcs  ...                           None
#
#   entities.description.mentions entities.description.urls entities.url.urls  \
# 0                          None                      None              None
#
#   public_metrics.followers_count public_metrics.following_count  \
# 0                         7316.0                          215.0
#
#    public_metrics.listed_count  public_metrics.tweet_count  \
# 0                         69.0                      3098.0
#
#    withheld.country_codes  label
# 0                    None  human
#
# [1 rows x 22 columns]
